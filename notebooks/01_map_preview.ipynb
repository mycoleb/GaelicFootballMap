# %% [markdown]
# # GAA Clubs GeoMap\n\nThis notebook loads data/raw/gaa_clubs.csv and renders the Folium map.\n

# %%
import pandas as pd\nfrom pathlib import Path\nimport sys\n\nROOT = Path.cwd().parent if (Path.cwd().name == 'notebooks') else Path.cwd()\nsys.path.append(str(ROOT / 'src'))\n\nfrom utils.data import load_clubs\nimport make_map\n\ndf = load_clubs(ROOT / 'data' / 'raw' / 'gaa_clubs.csv')\nm = make_map.build_map(df)\nm
